# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = [
    13.4,13.8,14.4,14.7,14.8,14.4,13.9,13.0,13.0,12.8,12.5,12.3,12.1,11.8,11.0,10.1,11.1,10.1,11.6,12.0,
    12.0,12.7,12.6,13.4,13.5,13.5,14.0,15.0,15.1,14.1,13.5,13.5,13.2,12.7,12.8,16.3,12.1,11.7,11.2,10.5,
    10.5,11.3,11.8,12.2,12.4,12.8,12.8,13.3,13.6,14.1,14.5,15.2,15.3,14.6,14.2,13.7,13.4,12.9,12.9,12.4,
    12.3,11.9,11.1,10.7,10.8,11.4,11.5,12.2,12.1,12.8,9.5,12.3,12.5,12.7,13.0,13.1,13.9,14.2,14.9,12.4,
    13.1,12.5,12.7,12.0,12.4,11.6,11.5,10.9,11.1,11.6,12.6,13.2,13.8,14.1,14.7,15.6,15.7,14.7,14.0,13.9
]

# %%
data = pd.Series(data)

# %%
print(
    "平均数：", round(data.mean(), 1), "\n"
    "中数：", data.median(), "\n"
    "众数：", data.mode()[0], "\n"
    "方差：", round(data.var(), 1), "\n"
    "标准差：", round(data.std(), 1), "\n"
    "变异系数：", round(data.mean() / data.std(),1), "\n"
)
# Out:
# 平均数： 12.9
# 中数： 12.8
# 众数： 12.8
# 方差： 1.9
# 标准差： 1.4
# 变异系数： 9.3

# %%
plt.rc('font',family='Times New Roman')
x = plt.hist(data, bins=7)
plt.plot(x[1][:7]+0.5, x[0])
plt.xlabel("Hemoglobin content (g/100 ml)")
plt.ylabel("Frequency")
plt.savefig("temp1.png",dpi=500,bbox_inches = 'tight')
plt.show()

# %%
import math

# %%
1 + math.log10(100)/math.log10(2)
# Out:
# 7.643856189774724

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)

# example data
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(437)

num_bins = 50

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(x, num_bins, density=1)

# add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
ax.plot(bins, y, '--')
ax.set_xlabel('Smarts')
ax.set_ylabel('Probability density')
ax.set_title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.show()
