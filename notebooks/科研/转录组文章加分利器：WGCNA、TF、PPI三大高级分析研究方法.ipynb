# %% [markdown]
# # 转录组文章加分利器：WGCNA、TF、PPI三大高级分析研究方法
#
# >2020年02月20日14:00观看于[美吉云课堂](http://edu.majorbio.com/)

# %% [markdown]
# ## WGCNA

# %% [markdown]
# ### 什么是WGCNA？

# %% [markdown]
# ![image.png](attachment:image.png)![image.png](attachment:image.png)

# %% [markdown]
# ## 为什么做WGCNA？

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 分析要求

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 样本
