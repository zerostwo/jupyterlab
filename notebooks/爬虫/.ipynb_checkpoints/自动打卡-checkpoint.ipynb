# %%
import requests

url = "http://xsc.sicau.edu.cn/SPCP/Web?tdsourcetag=s_pctim_aiomsg"

data = {
    "StuLoginMode": "1",
    "txtUid": "201702420",
    "txtPwd": "247652",
    "codeInput": ""
}

session=requests.session()

r=session.post(url, data=data)

url2 = "http://xsc.sicau.edu.cn/SPCP/Web/Report/Index"

data2 = {
    "StudentId": "201702420",
    "Name": "段松岐",
    "MoveTel": "15828820119",
    "Province": "510000",
    "City": "511000",
    "County": "511002",
    "ComeWhere": "白马镇凤鸣初级中学",
    "FaProvince": "510000",
    "FaCity": "511000",
    "FaCounty": "511002",
    "FaComeWhere": "白马镇凤鸣初级中学",
    "text_1": "",
    "radio_1": "08bbb0ac-3914-42b6-838e-68c01f9cef03",
    "text_2": "",
    "radio_2": "bcd21f69-7cec-4488-b300-71a45c705d7a",
    "text_3": "",
    "radio_3": "219e6c48-f926-49b5-8788-7b3b04f88a13",
    "text_4": "",
    "text_5": "",
    "radio_4": "cea433e2-7fce-42ec-87b5-8abd96c84c73",
    "text_6": "",
    "radio_5": "27c011b9-b7cd-4890-938e-5ee343df1f33",
    "text_7": "",
    "radio_6": "5f97cd9b-2bb1-406f-97db-8e55ca94197a",
    "text_8": "",
    "radio_7": "a4149ede-4565-411c-af5b-af5eb80e6b60",
    "radio_8": "b883a7dd-d433-4504-8b35-7492697b89e0",
    "text_9": "",
    "text_10": "",
    "radio_9": "5f1b9f15-604d-41ef-81a7-540445c91454",
    "text_11": "",
    "Other": "",
    "GetAreaUrl": "/SPCP/Web/Report/GetArea",
    "Sex": "男",
    "IdCard": "511002199905247652",
    "SpeType": "B",
    "CollegeNo": "15",
    "SpeGrade": "2017",
    "SpecialtyName": "食品科学与工程",
    "ClassName": "食工201702",
    "ProvinceName": "四川省",
    "CityName": "内江市",
    "CountyName": "市中区",
    "FaProvinceName": "四川省",
    "FaCityName": "内江市",
    "FaCountyName": "市中区",
    "radioCount": "9",
    "checkboxCount": "0",
    "blackCount": "11",
    "PZData": """[{"OptionName": "否", "SelectId": "08bbb0ac-3914-42b6-838e-68c01f9cef03",
      "TitleId": "c34ebc78-404c-47d7-a5bc-1acbd39c5d0c", "OptionType": "0"},
     {"OptionName": "否", "SelectId": "bcd21f69-7cec-4488-b300-71a45c705d7a",
      "TitleId": "ffabfdaf-a295-4de5-ae7b-840db175cbbb",
      "OptionType": "0"},
     {"OptionName": "否", "SelectId": "219e6c48-f926-49b5-8788-7b3b04f88a13",
      "TitleId": "2066497b-3828-48ab-bf94-360cec9b548a",
      "OptionType": "0"},
     {"OptionName": "以上症状都没有", "SelectId": "cea433e2-7fce-42ec-87b5-8abd96c84c73",
      "TitleId": "409f4a63-595f-487e-b1be-fd06090ad71e", "OptionType": "0"},
     {"OptionName": "否", "SelectId": "27c011b9-b7cd-4890-938e-5ee343df1f33",
      "TitleId": "b5503513-3bd4-44b6-be09-61b0eb2842e5",
      "OptionType": "0"},
     {"OptionName": "否", "SelectId": "5f97cd9b-2bb1-406f-97db-8e55ca94197a",
      "TitleId": "02f34fcd-d0d2-4556-90af-734bc24e692f",
      "OptionType": "0"},
     {"OptionName": "否", "SelectId": "a4149ede-4565-411c-af5b-af5eb80e6b60",
      "TitleId": "dc5107ab-161e-4516-a78e-aa24b6397965", "OptionType": "0"},
     {"OptionName": "居家", "SelectId": "b883a7dd-d433-4504-8b35-7492697b89e0",
      "TitleId": "f142c442-7bdd-4c85-a152-493030345b85",
      "OptionType": "0"},
     {"OptionName": "正常",
      "SelectId": "5f1b9f15-604d-41ef-81a7-540445c91454",
      "TitleId": "54334523-7b02-4c87-8187-f40b8b10948f",
      "OptionType": "0"}]"""
}
r2 = session.post(url2, data2)
file = open("./duansq.log", "a+")
print(r2.text, file=file)
file.close()
session.close()

# %%
import requests

url = "http://xsc.sicau.edu.cn/SPCP/Web?tdsourcetag=s_pctim_aiomsg"

data = {
    "StuLoginMode": "1",
    "txtUid": "201802641",
    "txtPwd": "173020",
    "codeInput": ""
}

session=requests.session()

r=session.post(url, data=data)

url2 = "http://xsc.sicau.edu.cn/SPCP/Web/Report/Index"

data2 = {
    "StudentId": "201802641",
    "Name": "张铭月",
    "MoveTel": "13541834802",
    "Province": "510000",
    "City": "511000",
    "County": "511002",
    "ComeWhere": "白马镇凤鸣初级中学",
    "FaProvince": "510000",
    "FaCity": "511000",
    "FaCounty": "511002",
    "FaComeWhere": "白马镇凤鸣初级中学",
    "text_1": "",
    "radio_1": "08bbb0ac-3914-42b6-838e-68c01f9cef03",
    "text_2": "",
    "radio_2": "bcd21f69-7cec-4488-b300-71a45c705d7a",
    "text_3": "",
    "radio_3": "219e6c48-f926-49b5-8788-7b3b04f88a13",
    "text_4": "",
    "text_5": "",
    "radio_4": "cea433e2-7fce-42ec-87b5-8abd96c84c73",
    "text_6": "",
    "radio_5": "27c011b9-b7cd-4890-938e-5ee343df1f33",
    "text_7": "",
    "radio_6": "5f97cd9b-2bb1-406f-97db-8e55ca94197a",
    "text_8": "",
    "radio_7": "a4149ede-4565-411c-af5b-af5eb80e6b60",
    "radio_8": "b883a7dd-d433-4504-8b35-7492697b89e0",
    "text_9": "",
    "text_10": "",
    "radio_9": "5f1b9f15-604d-41ef-81a7-540445c91454",
    "text_11": "",
    "Other": "",
    "GetAreaUrl": "/SPCP/Web/Report/GetArea",
    "Sex": "男",
    "IdCard": "511002199905247652",
    "SpeType": "B",
    "CollegeNo": "15",
    "SpeGrade": "2017",
    "SpecialtyName": "食品科学与工程",
    "ClassName": "食工201702",
    "ProvinceName": "四川省",
    "CityName": "内江市",
    "CountyName": "市中区",
    "FaProvinceName": "四川省",
    "FaCityName": "内江市",
    "FaCountyName": "市中区",
    "radioCount": "9",
    "checkboxCount": "0",
    "blackCount": "11",
    "PZData": """[{"OptionName": "否", "SelectId": "08bbb0ac-3914-42b6-838e-68c01f9cef03",
      "TitleId": "c34ebc78-404c-47d7-a5bc-1acbd39c5d0c", "OptionType": "0"},
     {"OptionName": "否", "SelectId": "bcd21f69-7cec-4488-b300-71a45c705d7a",
      "TitleId": "ffabfdaf-a295-4de5-ae7b-840db175cbbb",
      "OptionType": "0"},
     {"OptionName": "否", "SelectId": "219e6c48-f926-49b5-8788-7b3b04f88a13",
      "TitleId": "2066497b-3828-48ab-bf94-360cec9b548a",
      "OptionType": "0"},
     {"OptionName": "以上症状都没有", "SelectId": "cea433e2-7fce-42ec-87b5-8abd96c84c73",
      "TitleId": "409f4a63-595f-487e-b1be-fd06090ad71e", "OptionType": "0"},
     {"OptionName": "否", "SelectId": "27c011b9-b7cd-4890-938e-5ee343df1f33",
      "TitleId": "b5503513-3bd4-44b6-be09-61b0eb2842e5",
      "OptionType": "0"},
     {"OptionName": "否", "SelectId": "5f97cd9b-2bb1-406f-97db-8e55ca94197a",
      "TitleId": "02f34fcd-d0d2-4556-90af-734bc24e692f",
      "OptionType": "0"}, 
     {"OptionName": "否", "SelectId": "a4149ede-4565-411c-af5b-af5eb80e6b60",
      "TitleId": "dc5107ab-161e-4516-a78e-aa24b6397965", "OptionType": "0"},
     {"OptionName": "居家", "SelectId": "b883a7dd-d433-4504-8b35-7492697b89e0",
      "TitleId": "f142c442-7bdd-4c85-a152-493030345b85",
      "OptionType": "0"},
     {"OptionName": "正常",
      "SelectId": "5f1b9f15-604d-41ef-81a7-540445c91454",
      "TitleId": "54334523-7b02-4c87-8187-f40b8b10948f",
      "OptionType": "0"}]"""
}
r2 = session.post(url2, data2)
file = open("./duansq.log", "a+")
print(r2.text, file=file)
file.close()
session.close()
